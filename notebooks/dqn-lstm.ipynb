# %%
# add parent directory to path: enable import from parent dir
import sys
sys.path.append('../')

from environment import SmartBrokerEnv
from agents.dqn import DQN
from networks.lstm import LSTM

import matplotlib.pyplot as plt
import numpy as np
import torch.nn as nn
import torch

# %%
norm_cols = ['open', 'high', 'low', 'close', f'Volume XRP']
cols = ['date'] + norm_cols
batch_dur = 30
env = SmartBrokerEnv(
    batch_dur=batch_dur,
    df_info={
        'start_date': '2021-01-01',
        'end_date': '2021-05-01',
        'norm_cols': norm_cols,
        'cols': cols,
    },
    portfolio={

    },
)
# Out:
# /Users/vinay/miniforge3/lib/python3.9/site-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /Users/vinay/code/git/smart-broker/notebooks/../environment.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df['rolling_price'] = self.df[self.price_typ].rolling(self.roll_period).sum()
# /Users/vinay/miniforge3/lib/python3.9/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
batch_size = 100
target_net = LSTM(
    input_dim=batch_dur*3+3,
    output_dim=3,
)

policy_net = LSTM(
    input_dim=batch_dur*3+3,
    output_dim=3,
)

dqn = DQN(
    env=env,
    env_type='vector',
    n_actions=3,
    log_freq=5,
    train_freq=3,
    batch_size=batch_size,
    w_sync_freq=10,
    memory_size=10000,
    gamma=0.995,
    step_size=0.01,
    episodes=500,
    target_net=target_net,
    policy_net=policy_net,
    loss_func=nn.SmoothL1Loss(),
    optimizer=torch.optim.Adam(policy_net.parameters(), lr=0.0001),
    load_pretrained=False,
    save_pretrained=False,
    model_path='../models/dqn_lstm',
    network_type='lstm',
)

dqn.run(100)
# Out:
# collecting experience...
# 0..10..
# Ep: 20 | L: 0.21 | R: 54050.66 | R.Avg.R: 54050.66 | P: 25 | R.Avg P: 25 | B: 111 | R.Avg B: 111, N_Units: 1538
# Ep: 30 | L: 0.034 | R: 16789.57 | R.Avg.R: 31757.23 | P: 130 | R.Avg P: 106 | B: 34 | R.Avg B: 65, N_Units: 20385
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/78/_bz_v2_103ld252mxn9ml9c00000gn/T/ipykernel_4545/195862088.py in <module>
#      32 )
#      33
# ---> 34 dqn.run(100)
#
# ~/code/git/smart-broker/notebooks/../agents/dqn.py in run(self, ep)
#     267                     transitions = self.replay_memory.sample(self.batch_size)
#     268                     if timestep % self.train_freq == 0:
# --> 269                         ep_loss += self._train_one_batch(transitions, epsilon)
#     270
#     271                     if self.batch_no % self.w_sync_freq == 0:
#
# ~/code/git/smart-broker/notebooks/../agents/dqn.py in _train_one_batch(self, transitions, epsilon)
#     190
#     191         if self.network_type == 'lstm':
# --> 192             Q_values, _ = self.policy_net(
#     193                 states,
#     194                 self.train_hdn_st,
#
# ~/miniforge3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/code/git/smart-broker/notebooks/../networks/lstm.py in forward(self, x, prev_state)
#      25     def forward(self, x, prev_state):
#      26         x = x.view(x.shape[0], 1, self.input_dim)
# ---> 27         x, state = self.lstm(x, prev_state)
#      28         x = x.view(x.size(0), -1)
#      29         # x = F.relu(x)
#
# ~/miniforge3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/miniforge3/lib/python3.9/site-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     689         self.check_forward_args(input, hx, batch_sizes)
#     690         if batch_sizes is None:
# --> 691             result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
#     692                               self.dropout, self.training, self.bidirectional, self.batch_first)
#     693         else:
#
# ~/miniforge3/lib/python3.9/traceback.py in format_stack(f, limit)
#     195     if f is None:
#     196         f = sys._getframe().f_back
# --> 197     return format_list(extract_stack(f, limit=limit))
#     198
#     199
#
# ~/miniforge3/lib/python3.9/traceback.py in extract_stack(f, limit)
#     209     if f is None:
#     210         f = sys._getframe().f_back
# --> 211     stack = StackSummary.extract(walk_stack(f), limit=limit)
#     212     stack.reverse()
#     213     return stack
#
# ~/miniforge3/lib/python3.9/traceback.py in extract(klass, frame_gen, limit, lookup_lines, capture_locals)
#     345         result = klass()
#     346         fnames = set()
# --> 347         for f, lineno in frame_gen:
#     348             co = f.f_code
#     349             filename = co.co_filename
#
# ~/miniforge3/lib/python3.9/traceback.py in walk_stack(f)
#     299         f = sys._getframe().f_back.f_back
#     300     while f is not None:
# --> 301         yield f, f.f_lineno
#     302         f = f.f_back
#     303
#
# KeyboardInterrupt:

# %% [markdown]
# ### Visualizations

# %% [markdown]
# ### Traning

# %%
fig, ax = plt.subplots(2, 2, figsize=(16, 8))
r_avg_rewards = []
r_avg_profits = []
r_avg_bal = []
avg_units_held = []

for _, log in dqn.logs.items():
    r_avg_rewards.append(log['r_avg_reward'])
    r_avg_profits.append(log['r_avg_profit'])
    r_avg_bal.append(log['r_avg_bal'])
    avg_units_held.append(log['avg_units_held'])

ax[0][0].plot(range(len(r_avg_rewards)), r_avg_rewards)
ax[0][0].set_title('Rolling avg reward per episode')

ax[0][1].plot(range(len(r_avg_profits)), r_avg_profits)
ax[0][1].set_title('Rolling avg profit per episode')

ax[1][0].plot(range(len(r_avg_bal)), r_avg_bal)
ax[1][0].set_title('Rolling avg balance per episode')

ax[1][1].plot(range(len(avg_units_held)), avg_units_held)
ax[1][1].set_title('Average units held per episode')
# Out:
# Text(0.5, 1.0, 'Average units held per episode')
